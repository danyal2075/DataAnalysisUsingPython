# %%
import pandas as pd

# %%
# frist i load the xls file and then via parse we can read each sheet inside the data.
df = pd.ExcelFile('./yelp.xlsx')
# pd.set_option("display.max_rows" , df.shape[0]+1) # this is show the whole data set
print(df)

# %%
sheets = df.parse('yelp_data')
sheets
# Out:
# C:\Users\Danya\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# ...

# %%
sheets.dtypes
# Out:
# name             object
# category_0       object
# category_1       object
# take_out           bool
# review_count      int64
# stars           float64
# city_id           int64
# state_id          int64
# dtype: object

# %%
# i am loading second page
sheet1 = df.parse('cities')
sheet1
# Out:
# C:\Users\Danya\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#     id             city
# 0    1         Bellevue
# 1    2         Braddock
# 2    3         Carnegie
# 3    4        Homestead
# 4    5    Mc Kees Rocks
# 5    6    Mount Lebanon
# 6    7          Munhall
# 7    8       Pittsburgh
# 8    9   West Homestead
# 9   10     West Mifflin
# 10  11        Henderson
# 11  12        Las Vegas
# 12  13  North Las Vegas

# %%
# loading 3rd page
sheet2 = df.parse('states')
print(sheet2)
# Out:
# C:\Users\Danya\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    id state
# 0   1    PA
# 1   2    NV

# %%
sheets['category_0'].count() # this gives the how many times each element is repeated
# Out:
# 600

# %%
sheets['category_0'].value_counts()
# Out:
# Shopping                78
# Restaurants             71
# Food                    69
# Beauty & Spas           28
# Local Services          27
#                         ..
# Dermatologists           1
# Real Estate Services     1
# Animal Shelters          1
# Adult Entertainment      1
# Movers                   1
# Name: category_0, Length: 89, dtype: int64

# %%
sheets['category_0'].unique()
# Out:
# array(['Restaurants', 'Tires', 'Shopping', 'Food', 'Hair Salons',
#        'Beauty & Spas', 'Bars', 'Active Life', 'Automotive',
#        'Local Services', 'Public Services & Government',
#        'Hotels & Travel', 'Auto Repair', 'Breakfast & Brunch', 'Burgers',
#        'Pubs', 'Home Services', 'Health & Medical', 'Department Stores',
#        'Arts & Entertainment', 'Sporting Goods', 'Italian',
#        "Women's Clothing", "Men's Clothing", 'Seafood', 'Veterinarians',
#        'Gluten-Free', 'Nightlife', 'Piano Bars', 'Doctors', 'Car Wash',
#        'American (Traditional)', 'Gift Shops', 'Adult Entertainment',
#        'Event Planning & Services', 'Soup', 'Animal Shelters',
#        'Real Estate Services', 'American (New)', 'Opera & Ballet',
#        'Museums', 'Acupuncture', 'Greek', 'Barbers',
#        'Used, Vintage & Consignment', 'Fast Food', 'Optometrists',
#        'Massage', 'Skin Care', 'Oil Change Stations', 'Polish',
# ...

# %%
data = sheets[['name', 'city_id' , 'state_id']]
data
# Out:
#                                                   name  city_id  state_id
# 0                         China Sea Chinese Restaurant        1         1
# 1                                 Discount Tire Center        1         1
# 2                                         Frankfurters        1         1
# 3                                    Fred Dietz Floral        1         1
# 4                                        Kuhn's Market        1         1
# ..                                                 ...      ...       ...
# 595  Republic Services of Southern Nevada Recycling...       13         2
# 596                                       SA Recycling       13         2
# 597                                    Jack In the Box       13         2
# 598                               Custom Hearth & Door       13         2
# 599                                   A Sunrise Towing       13         2
#
# [600 rows x 3 columns]

# %%
# merging the data
sheets = pd.merge(left = sheets, right = sheet1, how = 'inner' , left_on = 'city_id', right_on = 'id')

# %%
sheets.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id      city
# 0            11    2.5        1         1   1  Bellevue
# 1            24    4.5        1         1   1  Bellevue
# 2             3    4.5        1         1   1  Bellevue
# 3             6    4.0        1         1   1  Bellevue
# 4             8    3.5        1         1   1  Bellevue

# %%
sheets = pd.merge(left = sheets , right = sheet2, how = 'inner', left_on = 'state_id', right_on = 'id')
sheets.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id_x      city  id_y state
# 0            11    2.5        1         1     1  Bellevue     1    PA
# 1            24    4.5        1         1     1  Bellevue     1    PA
# 2             3    4.5        1         1     1  Bellevue     1    PA
# 3             6    4.0        1         1     1  Bellevue     1    PA
# 4             8    3.5        1         1     1  Bellevue     1    PA

# %%
# Cleaening the data
del sheets['city_id']

# %%
# del sheets['state_id']

# %%
sheets
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1  take_out  review_count  stars  state_id  \
# ...

# %% [markdown]
# # filteration

# %%
# filteration
frist_100_bus = sheets[['name', 'city','state' ]]

# %%
frist_100_bus
# Out:
#                                                   name             city state
# 0                         China Sea Chinese Restaurant         Bellevue    PA
# 1                                 Discount Tire Center         Bellevue    PA
# 2                                         Frankfurters         Bellevue    PA
# 3                                    Fred Dietz Floral         Bellevue    PA
# 4                                        Kuhn's Market         Bellevue    PA
# ..                                                 ...              ...   ...
# 595  Republic Services of Southern Nevada Recycling...  North Las Vegas    NV
# 596                                       SA Recycling  North Las Vegas    NV
# 597                                    Jack In the Box  North Las Vegas    NV
# 598                               Custom Hearth & Door  North Las Vegas    NV
# 599                                   A Sunrise Towing  North Las Vegas    NV
#
# [600 rows x 3 columns]

# %%
Frank_data = sheets[(sheets['name']) == 'Frankfurters'].value_counts()

# %%
print(type(sheets))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(type(Frank_data))
# Out:
# <class 'pandas.core.series.Series'>

# %%
Frank_data.count()
# Out:
# 1

# %%
Frank_data
# Out:
# name          category_0   category_1  take_out  review_count  stars  state_id  id_x  city      id_y  state
# Frankfurters  Restaurants  Hot Dogs    True      3             4.5    1         1     Bellevue  1     PA       1
# dtype: int64

# %% [markdown]
# # Querying Data

# %%
# Slicing row
s_sheets = sheets[100:200]

# %%
s_sheets
# Out:
#                                        name      category_0  \
# 100                          Au Bon Pain Co            Food
# 101        Bado's Pizza Grill and Ale House         Italian
# 102                    Bastone Auto Service     Auto Repair
# 103               Bellisario's Pizza Palace         Italian
# 104  Benedum Center for the Performing Arts  Opera & Ballet
# ..                                      ...             ...
# 195                              McDonald's         Burgers
# 196                     Miller Ace Hardware        Shopping
# 197         Minutello's Restaurant & Lounge         Italian
# 198           Monro Muffler Brake & Service           Tires
# 199                           Moonlite Cafe     Restaurants
#
#                category_1  take_out  review_count  stars  state_id  id_x  \
# 100              Bakeries     False             7    3.0         1     8
# 101                  Bars      True            93    3.5         1     8
# ...

# %% [markdown]
# # Querying Data

# %%
#Querying Data
pitt = sheets['city'] == 'Pittsburgh'

# %%
sheets[pitt]
# Out:
#                                                name            category_0  \
# 95                              Aamco Transmissions           Auto Repair
# 96   Animal Rescue League Shelter & Wildlife Center       Animal Shelters
# 97                           Aracri's Greentree Inn               Italian
# 98                            Atch-Mont Real Estate  Real Estate Services
# 99                               Atria's Restaurant        American (New)
# ..                                              ...                   ...
# 283                             Walter's Automotive           Auto Repair
# 284                     Washington's Landing Marina           Active Life
# 285                             West Liberty Cycles        Sporting Goods
# 286                                  Wiseguys Pizza           Restaurants
# 287                                     X Shadyside           Active Life
#
#               category_1  take_out  review_count  stars  state_id  id_x  \
# ...

# %% [markdown]
# # Obj :
# searching for italian in city pittsburg

# %%
filtering = sheets[(sheets['city'] == 'Pittsburgh') & (sheets['category_0'] == 'Italian')]

# %%
filtering
# Out:
#                                  name category_0      category_1  take_out  \
# 97             Aracri's Greentree Inn    Italian  American (New)      True
# 101  Bado's Pizza Grill and Ale House    Italian            Bars      True
# 103         Bellisario's Pizza Palace    Italian           Pizza      True
# 146                Eddie's Pizza Haus    Italian           Pizza      True
# 153                  Fiori's Pizzaria    Italian           Pizza      True
# 172                      Il Pizzaiolo    Italian           Pizza      True
# 197   Minutello's Restaurant & Lounge    Italian           Pizza      True
# 229                         Pizza Hut    Italian           Pizza      True
#
#      review_count  stars  state_id  id_x        city  id_y state
# 97             15    3.5         1     8  Pittsburgh     1    PA
# 101            93    3.5         1     8  Pittsburgh     1    PA
# 103            21    3.5         1     8  Pittsburgh     1    PA
# ...

# %%
sheets['city'].unique()
# Out:
# array(['Bellevue', 'Braddock', 'Carnegie', 'Homestead', 'Mc Kees Rocks',
#        'Mount Lebanon', 'Munhall', 'Pittsburgh', 'West Homestead',
#        'West Mifflin', 'Henderson', 'Las Vegas', 'North Las Vegas'],
#       dtype=object)

# %% [markdown]
# # Obj
# apply two conditions in to the one column using isin() Method

# %%
# apply two conditions in to the one column
filtering_two_citeis = sheets[(sheets['city'].isin(['Pittsburgh', 'Homestead'])) & (sheets['category_0'] == 'Italian')]

# %%
filtering_two_citeis
# Out:
#                                  name category_0      category_1  take_out  \
# 48              Homestead Capri Pizza    Italian           Pizza      True
# 97             Aracri's Greentree Inn    Italian  American (New)      True
# 101  Bado's Pizza Grill and Ale House    Italian            Bars      True
# 103         Bellisario's Pizza Palace    Italian           Pizza      True
# 146                Eddie's Pizza Haus    Italian           Pizza      True
# 153                  Fiori's Pizzaria    Italian           Pizza      True
# 172                      Il Pizzaiolo    Italian           Pizza      True
# 197   Minutello's Restaurant & Lounge    Italian           Pizza      True
# 229                         Pizza Hut    Italian           Pizza      True
#
#      review_count  stars  state_id  id_x        city  id_y state
# 48              4    2.0         1     4   Homestead     1    PA
# 97             15    3.5         1     8  Pittsburgh     1    PA
# ...

# %%
sheets['category_0'].unique()
# Out:
# array(['Restaurants', 'Tires', 'Shopping', 'Food', 'Hair Salons',
#        'Beauty & Spas', 'Bars', 'Active Life', 'Automotive',
#        'Local Services', 'Public Services & Government',
#        'Hotels & Travel', 'Auto Repair', 'Breakfast & Brunch', 'Burgers',
#        'Pubs', 'Home Services', 'Health & Medical', 'Department Stores',
#        'Arts & Entertainment', 'Sporting Goods', 'Italian',
#        "Women's Clothing", "Men's Clothing", 'Seafood', 'Veterinarians',
#        'Gluten-Free', 'Nightlife', 'Piano Bars', 'Doctors', 'Car Wash',
#        'American (Traditional)', 'Gift Shops', 'Adult Entertainment',
#        'Event Planning & Services', 'Soup', 'Animal Shelters',
#        'Real Estate Services', 'American (New)', 'Opera & Ballet',
#        'Museums', 'Acupuncture', 'Greek', 'Barbers',
#        'Used, Vintage & Consignment', 'Fast Food', 'Optometrists',
#        'Massage', 'Skin Care', 'Oil Change Stations', 'Polish',
# ...

# %% [markdown]
# # obj
# Filtering the data for the dive bar in las vegas city having higher rating than 4. and then we recommend any bar using
# random Method

# %%
filteration_dive_bar = sheets[(sheets['city'] == 'Las Vegas') & ((sheets['category_0'] == 'Dive Bars') | 
                                                                 (sheets['category_1'] == 'Dive Bars')) & (sheets['stars'] >= 4)]

# %%
len(filteration_dive_bar)
# Out:
# 2

# %%
filteration_dive_bar
# Out:
#                  name category_0 category_1  take_out  review_count  stars  \
# 451  Huntridge Tavern  Dive Bars       Bars     False            50    4.0
# 453      Moon Doggies  Dive Bars       Bars     False            85    4.0
#
#      state_id  id_x       city  id_y state
# 451         2    12  Las Vegas     2    NV
# 453         2    12  Las Vegas     2    NV

# %%
sheets[sheets['category_0']== 'Nail Salon'].value_counts() # how many nail salon are there in the
# Out:
# Series([], dtype: int64)

# %%
#using random number
import random
filtering_rand_bar =  random.randint(0, len(filteration_dive_bar)-1) # generating rand number 
rand_dive_bar = filteration_dive_bar[filtering_rand_bar:filtering_rand_bar+1] # here we are defining which row number 
rand_dive_bar
# Out:
#                  name category_0 category_1  take_out  review_count  stars  \
# 451  Huntridge Tavern  Dive Bars       Bars     False            50    4.0
#
#      state_id  id_x       city  id_y state
# 451         2    12  Las Vegas     2    NV

# %%
filteration_dive_bar[1:2] # just for confirmation it did it manually
# Out:
#              name category_0 category_1  take_out  review_count  stars  \
# 453  Moon Doggies  Dive Bars       Bars     False            85    4.0
#
#      state_id  id_x       city  id_y state
# 453         2    12  Las Vegas     2    NV

# %% [markdown]
# # Cumputation :
# we are using sum() method to add all the int values
# # Task:
# we are going to count the review for 'Food' in Pittsburg City
#
# # .str.contains()
# cat0_food = sheets['category_0'].str.contains('Food')
#
# it gives all the rows where food will be found with some other string like (Fast Food)
#
# cat0_food = sheets['category_0'] == 'Food'
#
# second filteration method will just filter rows containing only 'food' string. it will also drop 'Fast Food'

# %%
# Creating filters
cat0_food = sheets['category_0'].str.contains('Food') 
cat1_food = sheets['category_1'].str.contains('Food')
pittsburg_food = sheets['city'] == 'Pittsburgh'

# %%
# Applying filters
final_food = sheets[ ((cat0_food | cat1_food) & pittsburg_food)]
final_food
# Out:
#                                     name category_0  \
# 100                       Au Bon Pain Co       Food
# 106                    Better-Maid Donut       Food
# 110                           BreadWorks       Food
# 113                    Bruegger's Bagels       Food
# 129                    Cool Beans Coffee       Food
# 132        Crouse Wayne Beer Distributor       Food
# 134                          Dairy Queen       Food
# 144                Eat'n Park Restaurant  Fast Food
# 154             Fortunes Coffee Roastery       Food
# 159                          Giant Eagle       Food
# 160                          Giant Eagle       Food
# 161                          Giant Eagle       Food
# 162                          Giant Eagle       Food
# 174            Jade 99 Asian Supermarket       Food
# 180                            Katerbean       Food
# 182            Klavon's Ice Cream Parlor       Food
# 186                 La Prima Espresso Co       Food
# ...

# %%
# Counting Reviews
count_review_pittsburg_food = final_food['review_count'].sum()
count_review_pittsburg_food
# Out:
# 1412

# %% [markdown]
# # Task:
# calculate the average/ mean of the auto repair shops in pittsburg using mean() method

# %%
# creating filters
cat0_autoshop = sheets['category_0'].str.contains('Auto Repair')
cat1_autoshop = sheets['category_1'].str.contains('Auto Repair')
pittsburg = sheets['city'] == 'Pittsburgh'
# applying filters
final_data_auto = sheets[((cat0_autoshop |cat1_autoshop ) & pittsburg)  ]
final_data_auto
# Out:
#                             name   category_0  category_1  take_out  \
# 95           Aamco Transmissions  Auto Repair  Automotive     False
# 102         Bastone Auto Service  Auto Repair  Automotive     False
# 111          Broadway Auto Parts  Auto Repair  Automotive     False
# 137  Dependable Brakes & Exhaust  Auto Repair  Automotive     False
# 245           Ruffing Automotive  Auto Repair  Automotive     False
# 283          Walter's Automotive  Auto Repair  Automotive     False
#
#      review_count  stars  state_id  id_x        city  id_y state
# 95             21    4.5         1     8  Pittsburgh     1    PA
# 102            20    4.0         1     8  Pittsburgh     1    PA
# 111             4    5.0         1     8  Pittsburgh     1    PA
# 137             4    5.0         1     8  Pittsburgh     1    PA
# 245             3    3.5         1     8  Pittsburgh     1    PA
# 283            99    5.0         1     8  Pittsburgh     1    PA

# %%
# getting mean of the data
mean_auto = final_data_auto['review_count'].mean()
mean_auto
# Out:
# 25.166666666666668

# %% [markdown]
# # Updating and Creating data:
# here we study how to update and create data using different methods
#
# You can easily create new columns in a data frame by just naming them uniquely and using them
#
# We can add different columns together in the new categories and then delete the old one.

# %% [markdown]
# # Task1:
# Add new column 'Country' to the data and asign value 'US' to the data

# %%
sheets['Country'] = 'US' # just write down one = 
sheets
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1  take_out  review_count  stars  state_id  \
# ...

# %% [markdown]
# # Task 2:
# Combine cat0 and cat1 columns and make an another columns 'Categories' and put those two columns in the new one

# %%
sheets['Categories'] = sheets['category_0'].str.cat(sheets['category_1'], sep =',')
sheets
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1  take_out  review_count  stars  state_id  \
# ...

# %% [markdown]
# # Task 3:
# Add a new column into the data 'Rating' and put the star val in that column in term of 10. and then print the result.

# %%
# creating new row
sheets['Rating'] = sheets['stars'] * 2
sheets
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1  take_out  review_count  stars  state_id  \
# ...

# %%
# making function to update the rating col
def update_rating(x):
    return(str(x) + '  out of 10')

# %%
sheets['Rating'] = sheets['Rating'].apply(update_rating)
sheets
# Out:
#                                                   name      category_0  \
# 0                         China Sea Chinese Restaurant     Restaurants
# 1                                 Discount Tire Center           Tires
# 2                                         Frankfurters     Restaurants
# 3                                    Fred Dietz Floral        Shopping
# 4                                        Kuhn's Market            Food
# ..                                                 ...             ...
# 595  Republic Services of Southern Nevada Recycling...  Local Services
# 596                                       SA Recycling  Local Services
# 597                                    Jack In the Box     Restaurants
# 598                               Custom Hearth & Door        Shopping
# 599                                   A Sunrise Towing      Automotive
#
#                           category_1  take_out  review_count  stars  state_id  \
# ...

# %% [markdown]
# # Task 4:
#     delete the cat1 and cat2 columns

# %%
del sheets['category_0']
del sheets['category_1']
sheets
# Out:
#                                                   name  take_out  \
# 0                         China Sea Chinese Restaurant      True
# 1                                 Discount Tire Center     False
# 2                                         Frankfurters      True
# 3                                    Fred Dietz Floral     False
# 4                                        Kuhn's Market     False
# ..                                                 ...       ...
# 595  Republic Services of Southern Nevada Recycling...     False
# 596                                       SA Recycling     False
# 597                                    Jack In the Box      True
# 598                               Custom Hearth & Door     False
# 599                                   A Sunrise Towing     False
#
#      review_count  stars  state_id  id_x             city  id_y state Country  \
# 0              11    2.5         1     1         Bellevue     1    PA      US
# ...

# %%
del sheets['category_1']
sheets
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'category_1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
